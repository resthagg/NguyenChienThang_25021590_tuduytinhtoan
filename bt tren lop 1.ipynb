# %%
a=float(input("Nhap so diem:"))
if a>=8:
    print("hoc luc gioi")
elif a>=6.5:
    print("hoc luc kha")
elif a>=5:
    print("hoc luc trung binh")
else:
    print("hoc luc yeu")
# Out:
# hoc luc gioi
