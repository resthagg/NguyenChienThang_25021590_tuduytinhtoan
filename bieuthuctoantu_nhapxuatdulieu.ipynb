# %%
#bai W2A1
print ("Hello World!")
# Out:
# Hello World!

# %%
#bai W2A2
x=input("ten ban la gi:")
print ("Xin chao", x)
# Out:
# Xin chao Nguyen Chien Thang

# %%
#bai W2A3
a=int(input("so thu 1 la:"))
b=int(input("so thu 2 la:"))
c= a + b
d= a - b
e= a * b
f= a // b
g= a % b
h= a/b
j=round(h, 2 )
print(c,d,e,f,g,j, sep=" , ")
# Out:
# 6563 , 4967 , 4600470 , 7 , 179 , 7.22

# %%
#bai W2A4
a1,b1,c1,a2,b2,a3 = map(float, input("Nhap diem 6 mon hoc: ").split())
TB = ((a1+b1+c1)+(a2+b2)*2+a3*3)/10
c=round(TB,1)
print("Diem trung binh 6 mon hoc la:", c)
# Out:
# Diem trung binh 6 mon hoc la: 4.8

# %%
#bai W2A5
a,b = map(int, input("Nhap 2 so nguyen:").split())
c=a**b
print(c)
# Out:
# 8

# %%
#bai W2A6
a = input("Nhap chu cai thuong:")
print(ord(a))
print("chu cai in hoa la:", a.upper())
# Out:
# 97
# chu cai in hoa la: A

# %%
#bai W2A7
A=((13**2)*3)+5
B=13**2*3+5
print("kq A:", A)
print("kq B:", B)
# Out:
# kq A: 512
# kq B: 512

# %%
#bai W2A8
a=float(input("nhap nhiet do:"))
F=9/5*a+32
b=round(F,2)
print("nhiet do theo thang Fahrenheit la:", b, "do F")
# Out:
# nhiet do theo thang Fahrenheit la: 2192.24 do F

# %%
#bai W2A9
a=float(input("gia chiec dong ho la:"))
b=a+10
c=1*0.3
d=1*0.1
e=a+b+c+d
f=round(e,2)
print("tong so tien phai tra la:", f, end= "usd")
# Out:
# tong so tien phai tra la: 60010.4usd

# %%
#bai W2A10
a,b,c=(input("nhap ten ba nguoi:").split())
print("Hi",c,b, sep=",", end=" and ")
print(a)
# Out:
# Hi,dung,minh and thang

# %%
#bai W2A11
a=int(input("nhap so gio:"))
b=int(input("nhap so phut:"))
c=a*3600+b*60
print(a, "gio", b , "phut bang", c, "giay" )
# Out:
# 10 gio 30 phut bang 37800 giay

# %%
#bai W2A12
a=int(input("do dai canh cuc rubik la:"))
b=a*a*6
print("so mieng dan can thiet la:",b, "mieng")
# Out:
# so mieng dan can thiet la: 96 mieng

# %%
#bai W2A13
a=int(input("nhap so nguyen duong a:"))
b=int(input("nhap so nguyen duong b:"))
if a<=0 or b<=0:
    print("Vui long nhap so nguyen duong.")
else:
    c=a*b
    d=c%10
    print("don vi cua tich a*b la:", d)
# Out:
# don vi cua tich a*b la: 6

# %%
#bai W2A14
a=float(input("nhap so a:"))
b=float(input("nhap so b:"))
print("gia tri ban dau cua a =",a , "cua b =",b)
a,b=b,a 
print("gia tri sau khi hoan doi cua a =",a , "cua b =",b)
# Out:
# gia tri ban dau cua a = 313.3 cua b = 223.5
# gia tri sau khi hoan doi cua a = 223.5 cua b = 313.3

# %%
#bai W2A15
n = int(input("nhap so nguyen duong n: "))
if n <= 0:
    print("Vui lòng nhập một số nguyên dương hợp lệ.")
else:
    sosao = 3 * n * (n - 1) + 1
    print("Số sao thứ n là:", sosao)
# Out:
# Số sao thứ n là: 271

# %%
#bai W2A16
print("""SPRING
SUMMER
AUTUMN
WINTER""")
# Out:
# SPRING
# SUMMER
# AUTUMN
# WINTER

# %%
#bai W2A17
print("* ")
print("***")
print("*****")
# Out:
# *
# ***
# *****

# %%
#bai W2A18
print("""### # #  ### ###
 #  #  #  #   #
 #  #   # #   #
 #  #  #  #   #
 #  # #   #   #""")
# Out:
# ### # #  ### ###
#  #  #  #  #   #
#  #  #   # #   #
#  #  #  #  #   #
#  #  # #   #   #

# %%
#bai W2A19
print("""MONDAY
TUESDAY
WEDNESDAY
THURSDAY
FRIDAY
SATURDAY
SUNDAY
""")
# Out:
# MONDAY
# TUESDAY
# WEDNESDAY
# THURSDAY
# FRIDAY
# SATURDAY
# SUNDAY

# %%
#bai W2A20
print('''JANUARY
FEBRUARY
MARCH
APRIL
MAY
JUNE
JULY
AUGUST
SEPTEMBER
OCTOBER
NOVEMBER
DECEMBER
''')
# Out:
# JANUARY
# FEBRUARY
# MARCH
# APRIL
# MAY
# JUNE
# JULY
# AUGUST
# SEPTEMBER
# OCTOBER
# NOVEMBER
# DECEMBER

# %%
#bai W2A21
for i in range(10):
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
