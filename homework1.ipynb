# %%
#bai 1
n=int(input("nhap so nguyen n:"))
a=2*n
print("2n bang:",a)
# Out:
# 2n bang: 46

# %%
#bai 2
a = float(input("nhap chieu rong manh dat:"))
b = float(input("nhap chieu dai manh dat:"))
S = (a*b)-(3.14*((a/2)**2))
S1 = round(S, 2)
print("dien tich con de trong cay la:", S1)
# Out:
# dien tich con de trong cay la: 294.96

# %%
#bai 3
a = input("nhap chu a:")
if a.islower():
    print("chu in hoa:", a.upper())
else:
    print("chu in thuong:", a.lower())
# Out:
# chu in thuong: a

# %%
#bai 4
a = input("nhap chu cai bat ky:")
if a >= "a"and a<= "z"or a>= "A" and a<="Z":
    print(a,"la ki tu alphabet")
else:
    print(a,"khong phai ki tu alphabet")
# Out:
# H la ki tu alphabet

# %%
#bai 5
a = input("Nhap ky tu in hoa bat ky:")
if a.islower():
    print("hay nhap ky tu in hoa!")
elif a == "A":
    print("chu cai lien truoc chu A in thuong la:", "z")
else:
    c=chr(ord(a)+31)
    print("chu cai lien truoc chu ", a, "in thuong la:", c)
# Out:
# chu cai lien truoc chu  B in thuong la: a

# %%
#bai 6
a=float(input("nhap so a:"))
b=float(input("nhap so b:"))
c=float(input("nhap so c:"))
if a+b>c and a+c>b and b+c>a:
    print("3 canh tren tao thanh tam giac")
    p=(a+b+c)/2
    S=(p*(p-a)*(p-b)*(p-c))**0.5
    print("dien tich tam giac la:", round(S,1))
else:
    print("3 canh tren khong tao thanh tam giac")
# Out:
# 3 canh tren tao thanh tam giac
# dien tich tam giac la: 15.2

# %%
#bai 7
a=input("nhap vao mot chuoi ky tu thuong co do dai >=20:")
if len(a)<=20:
    print("chuoi ky tu khong hop le, yeu cau nhap lai!")
else:
    b=a[4]
    c=a[8]
    print("chu cai thu 5 la:",b)
    print("chu cai thu 9 la:",c)
# Out:
# chu cai thu 5 la: g
# chu cai thu 9 la: f

# %%
a=input("nhap ho ten chu ho:")
b=int(input("nhap so dien ke thang truoc :"))
c=int(input("nhap so dien ke thang nay:"))
d=c-b
if b>c:
    print("vui long nhap lai so dien")
else:
    print("Ho va ten:",a)
    if 0<=d<=50:
       e=d*1984
       f=e*0.08
       g=e+f
       print("Tien phai tra la: ",round(g))
    elif 51<=d<=100:
        e=50*1984+(d-50)*2050
        f=e*0.08
        g=e+f
        print("Tien phai tra la: ",round(g))
    elif 101<=d<=200:
        e=50*1984+50*2050+(d-100)*2380
        f=e*0.08
        g=e+f
        print("Tien phai tra la: ",round(g))
    elif 201<=d<=300:
        e=50*1984+50*2050+100*2380+(d-200)*2998
        f=e*0.08
        g=e+f
        print("Tien phai tra la: ",round(g))
    elif 301<=d<=400:
        e=50*1984+50*2050+100*2380+100*2998+(d-300)*3350
        f=e*0.08
        g=e+f
        print("Tien phai tra la: ",round(g))
    else:
        e=50*1984+50*2050+100*2380+100*2998+100*3350+(d-400)*3460
        f=e*0.08
        g=e+f
        print("Tien phai tra la: ",round(g))
# Out:
# Ho va ten: Nguyen Xuan Hai
# Tien phai tra la:  1855505
